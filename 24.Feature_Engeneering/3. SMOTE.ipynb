# %% [markdown]
# ## SMOTE [synthetic Minority Oversampling Technique]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1, 
                           weights=[0.90], random_state=120)

# %%
df1 = pd.DataFrame(X, columns = ['f1','f2'])
df2 = pd.DataFrame(y, columns = ['target'])
final_df = pd.concat([df1,df2], axis = 1)
final_df.target.value_counts()
# Out:
# target
# 0    898
# 1    102
# Name: count, dtype: int64

# %%
sns.scatterplot(data = final_df, x = 'f1', y = 'f2', hue = 'target')
# Out:
# <Axes: xlabel='f1', ylabel='f2'>

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in c:\users\bhard\downloads\anaconda3\lib\site-packages (from imblearn) (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\bhard\downloads\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\bhard\downloads\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\bhard\downloads\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\bhard\downloads\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bhard\downloads\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X, y= oversample.fit_resample(final_df[['f1','f2']],final_df['target'])
X.shape
# Out:
# (1796, 2)

# %%
df1 = pd.DataFrame(X, columns = ['f1','f2'])
df2 = pd.DataFrame(y, columns = ['target'])
final_df1 = pd.concat([df1,df2], axis = 1)
final_df1.target.value_counts()
# Out:
# target
# 0    898
# 1    898
# Name: count, dtype: int64

# %%
sns.scatterplot(data=final_df1, x = 'f1', y = 'f2', hue = 'target')
# Out:
# <Axes: xlabel='f1', ylabel='f2'>
