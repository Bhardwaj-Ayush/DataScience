# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header = 1)
data.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# # EDA for the dataset

# %%
# handling missing values

data[data.isnull().any(axis = 1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df = data.dropna().reset_index(drop = True)

# %%
df.loc[:122, "Region"] = 0
df.loc[122:, "Region"] = 1

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df = df.drop(122).reset_index(drop = True)

# %%
df.loc[122]
# Out:
# day                     01
# month                   06
# year                  2012
# Temperature             32
#  RH                     71
#  Ws                     12
# Rain                   0.7
# FFMC                  57.1
# DMC                    2.5
# DC                     8.2
# ISI                    0.6
# BUI                    2.8
# FWI                    0.2
# Classes        not fire
# Region                 1.0
# Name: 122, dtype: object

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4    RH          243 non-null    object
#  5    Ws          243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 28.6+ KB

# %%
df1 = df

# %%
# df = df.drop(columns = ['day', 'month', 'year'])

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire        0.0
# ...

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
# df[['Temperature', ' RH', ' Ws']] = df[['Temperature', ' RH', ' Ws']].astype(int)
df[['Temperature', 'RH', 'Ws']] = df[['Temperature', 'RH', 'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    float64
# dtypes: float64(1), int32(3), object(11)
# memory usage: 25.8+ KB

# %%
# df[['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']] = df[['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']].astype(float)
# or

objects = [features for features in df.columns if df[features].dtype == 'O']

for object in objects:
    if object!= 'Classes':
        df[object] = df[object].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    float64
#  2   year         243 non-null    float64
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    float64
# dtypes: float64(11), int32(3), object(1)
# memory usage: 25.8+ KB

# %%
df.head()
# Out:
#    day  month    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0  1.0    6.0  2012.0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1  2.0    6.0  2012.0           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2  3.0    6.0  2012.0           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3  4.0    6.0  2012.0           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4  5.0    6.0  2012.0           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire        0.0
# 1  0.4  not fire        0.0
# 2  0.1  not fire        0.0
# 3  0.0  not fire        0.0
# 4  0.5  not fire        0.0

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
# finding outliers

min, Q1, median, Q3, max = np.quantile(df['Temperature'], [0,0.25, 0.5, 0.75, 1.0])

# %%
IQR = Q3 - Q1

# %%
Lower_fence = Q1 - 1.5*(IQR)

# %%
Higher_fence = Q3 + 1.5*(IQR)

# %%
print(Lower_fence)
print(Higher_fence)
# Out:
# 22.5
# 42.5

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0, 1 )

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
sns.histplot(df, bins = 50)
# Out:
# <Axes: ylabel='Count'>

# %%
for col in df.select_dtypes(include='number').columns:
    sns.histplot(df[col], kde=True, bins=50)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
df1.head()
# Out:
#    day  month    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0  1.0    6.0  2012.0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1  2.0    6.0  2012.0           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2  3.0    6.0  2012.0           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3  4.0    6.0  2012.0           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4  5.0    6.0  2012.0           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Region
# 0  0.5        0     0.0
# 1  0.4        0     0.0
# 2  0.1        0     0.0
# 3  0.0        0     0.0
# 4  0.5        0     0.0

# %%
# monthly fire analysis 

df_fire = df.loc[df['Region'] == 0]
sns.countplot(x = 'month', hue = 'Rain' , data = df_fire)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
df.drop(['day'	,'month'	,'year'], axis = 1, inplace = True).reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[439], line 1
# ----> 1 df.drop(['day'	,'month'	,'year'], axis = 1, inplace = True).reset_index(drop = True)
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0     0.0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0     0.0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0     0.0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0     0.0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0     0.0

# %%
df.to_csv("Algerian_forest_fires_dataset_cleaned.csv")
